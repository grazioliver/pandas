# %% [markdown]
# <a href="https://colab.research.google.com/github/grazioliver/pandas/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
arac = pd.read_excel("/content/Aracaju.xlsx")
fort = pd.read_excel("/content/Fortaleza.xlsx")
natal = pd.read_excel("/content/Natal.xlsx")
recife = pd.read_excel("/content/Recife.xlsx")
salv = pd.read_excel("/content/Salvador.xlsx")

# %%
df = pd.concat([arac,fort,natal,recife,salv])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df["LojaID"] = df["LojaID"].astype("object")

# %%
df['Vendas'].mean()
# Out:
# 122.61180089485458

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df['Vendas'].fillna(0, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.dropna(subset=['Vendas'], inplace=True)

# %%
df.dropna(how='all', inplace=True)

# %%
df.sample()
# Out:
#        Cidade       Data  Vendas LojaID  Qtde
# 232  Salvador 2019-01-03  167.76   1034     3

# %%
df.dropna(inplace=True)

# %%
df["Receita"] = df ['Vendas'].mul(df['Qtde'])

# %%
df.head()
# Out:
#     Cidade                 Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju  1514764800000000000  142.00   1520     1   142.00
# 1  Aracaju  1514764800000000000   14.21   1522     6    85.26
# 2  Aracaju  1514764800000000000   71.55   1520     1    71.55
# 3  Aracaju  1514764800000000000    3.01   1521     7    21.07
# 4  Aracaju  1514764800000000000   24.51   1522     8   196.08

# %%
df['Receita/Vendas'] = df['Receita']/ df['Vendas']

# %%
df.head()
# Out:
#     Cidade                 Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 0  Aracaju  1514764800000000000  142.00   1520     1   142.00             1.0
# 1  Aracaju  1514764800000000000   14.21   1522     6    85.26             6.0
# 2  Aracaju  1514764800000000000   71.55   1520     1    71.55             1.0
# 3  Aracaju  1514764800000000000    3.01   1521     7    21.07             7.0
# 4  Aracaju  1514764800000000000   24.51   1522     8   196.08             8.0

# %%
df['Receita'].max()
# Out:
# 3544.0

# %%
df.nlargest(3, 'Receita')
# Out:
#    Cidade                 Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal  1552867200000000000   886.0    853     4   3544.0             4.0
# 51  Natal  1516492800000000000   859.0    852     4   3436.0             4.0
# 55  Natal  1546905600000000000   859.0    854     4   3436.0             4.0

# %%
df.nsmallest(5, 'Receita')
# Out:
#        Cidade                 Data  Vendas LojaID  Qtde  Receita  \
# 118   Aracaju  1514764800000000000    3.34   1522     1     3.34
# 65     Recife  1546300800000000000    4.01    981     1     4.01
# 92      Natal  1546387200000000000    4.57   1035     1     4.57
# 92   Salvador  1546300800000000000    4.57   1035     1     4.57
# 95      Natal  1546387200000000000    5.13   1035     1     5.13
#
#      Receita/Vendas
# 118             1.0
# 65              1.0
# 92              1.0
# 92              1.0
# 95              1.0

# %%
df.groupby('Cidade')["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df.sort_values('Receita', ascending=False).head(10)
# Out:
#    Cidade                 Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal  1552867200000000000   886.0    853     4   3544.0             4.0
# 55  Natal  1546905600000000000   859.0    854     4   3436.0             4.0
# 51  Natal  1516492800000000000   859.0    852     4   3436.0             4.0
# 30  Natal  1538438400000000000   856.0    853     4   3424.0             4.0
# 41  Natal  1526774400000000000   835.0    852     4   3340.0             4.0
# 38  Natal  1519516800000000000   828.0    852     4   3312.0             4.0
# 10  Natal  1540598400000000000   828.0    852     4   3312.0             4.0
# 69  Natal  1553385600000000000   817.0    852     4   3268.0             4.0
# 62  Natal  1518220800000000000   793.0    854     4   3172.0             4.0
# 52  Natal  1524787200000000000   778.0    854     4   3112.0             4.0

# %%
df['Data'] = df['Data'].astype('int64')

# %%
df.dtypes
# Out:
# Cidade      object
# Data         int64
# Vendas     float64
# LojaID      object
# Qtde         int64
# Receita    float64
# dtype: object

# %%
df['Data'] = pd.to_datetime(df['Data'])

# %%
df.dtypes
# Out:
# Cidade                    object
# Data              datetime64[ns]
# Vendas                   float64
# LojaID                    object
# Qtde                       int64
# Receita                  float64
# Receita/Vendas           float64
# dtype: object

# %%
df.groupby(df['Data'].dt.year)['Receita'].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
df['Ano_Venda'] = df['Data'].dt.year

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 7     Aracaju 2019-01-01  172.22   1522     6  1033.32             6.0
# 205  Salvador 2019-01-02  196.09   1037     1   196.09             1.0
# 6    Salvador 2019-01-01   36.30   1034     2    72.60             2.0
# 128   Aracaju 2018-01-01   37.49   1521     2    74.98             2.0
# 188  Salvador 2019-01-02  178.11   1035     3   534.33             3.0
#
#      Ano_Venda  mes_venda  dia_venda
# 7         2019          1          1
# 205       2019          1          2
# 6         2019          1          1
# 128       2018          1          1
# 188       2019          1          2

# %%
df['mes_venda'], df['dia_venda'] = df['Data'].dt.month, df['Data'].dt.day

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 188  Salvador 2019-01-02  178.11   1035     3   534.33             3.0
# 155     Natal 2019-01-02  237.81   1036     3   713.43             3.0
# 196     Natal 2019-01-02  145.09   1036     2   290.18             2.0
# 34     Recife 2019-01-01   24.97    980     5   124.85             5.0
# 201     Natal 2019-01-02   86.61   1036     1    86.61             1.0
#
#      Ano_Venda  mes_venda  dia_venda
# 188       2019          1          2
# 155       2019          1          2
# 196       2019          1          2
# 34        2019          1          1
# 201       2019          1          2

# %%
df['Data'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
df['diferenca_dias'] = df['Data'] - df['Data'].min()

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 54   Salvador 2019-01-01   46.54   1037     3   139.62             3.0
# 161  Salvador 2019-01-02    5.80   1036     1     5.80             1.0
# 133  Salvador 2019-03-02  153.71   1035     1   153.71             1.0
# 224     Natal 2019-01-02  178.30   1035     3   534.90             3.0
# 158     Natal 2019-01-02  183.64   1037     3   550.92             3.0
#
#      Ano_Venda  mes_venda  dia_venda diferenca_dias
# 54        2019          1          1       365 days
# 161       2019          1          2       366 days
# 133       2019          3          2       425 days
# 224       2019          1          2       366 days
# 158       2019          1          2       366 days

# %%
df['trimestre_venda'] = df['Data'].dt.quarter

# %%
df.sample(5)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 193     Natal 2019-01-02    3.97   1036     2     7.94             2.0
# 78     Recife 2019-01-01  238.73    980     3   716.19             3.0
# 198     Natal 2019-01-02   13.65   1037     3    40.95             3.0
# 185     Natal 2019-01-02    6.67   1036     1     6.67             1.0
# 50   Salvador 2019-01-01   44.87   1036     3   134.61             3.0
#
#      Ano_Venda  mes_venda  dia_venda diferenca_dias  semestre_venda  \
# 193       2019          1          2       366 days               1
# 78        2019          1          1       365 days               1
# 198       2019          1          2       366 days               1
# 185       2019          1          2       366 days               1
# 50        2019          1          1       365 days               1
#
#      trimestre_venda
# 193                1
# 78                 1
# 198                1
# 185                1
# ...

# %%
vendas_marco_19 = df.loc[(df['Data'].dt.year == 2019) & (df['Data'].dt.month == 5) ]

# %%
df.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 204      Natal 2019-01-02  151.41   1037     2   302.82             2.0
# 61     Aracaju 2018-01-01   39.80   1520     6   238.80             6.0
# 96   Fortaleza 2019-01-01   23.31   1004     4    93.24             4.0
# 152      Natal 2019-01-02   20.07   1035     1    20.07             1.0
# 166      Natal 2019-01-02  111.72   1035     3   335.16             3.0
# 176      Natal 2019-01-02   19.42   1035     3    58.26             3.0
# 128     Recife 2019-03-02   38.70    982     4   154.80             4.0
# 4      Aracaju 2018-01-01   24.51   1522     8   196.08             8.0
# 177      Natal 2019-01-02   41.19   1037     2    82.38             2.0
# 48    Salvador 2019-01-01  127.28   1035     2   254.56             2.0
# 121   Salvador 2019-03-02  100.70   1037     3   302.10             3.0
# 67   Fortaleza 2019-01-01   43.51   1003     1    43.51             1.0
# ...

# %%
df['LojaID'].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df['LojaID'].value_counts(ascending=False).plot.bar()

# %%
df['LojaID'].value_counts(ascending=True).plot.barh();

# %%
df.groupby(df['Data'].dt.year)['Receita'].sum().plot.pie();

# %%
df['Cidade'].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
import matplotlib.pyplot as plt
df['Cidade'].value_counts().plot.bar(title='total vendas por cidade')
plt.xlabel('Cidade')
plt.ylabel('total vendas');

# %%
df['Cidade'].value_counts().plot.bar(title='total vendas por cidade', color='red')
plt.xlabel('cidade')
plt.ylabel('total vendas');

# %%
plt.style.use('ggplot')

# %%
df.groupby(df['mes_venda'])['Qtde'].sum().plot(title='total produtos vendidos por mes')
plt.xlabel('Mes')
plt.ylabel('Total Produtos Vendidos');
plt.legend()

# %%
df_2019 = df[df['Ano_Venda'] == 2019]

# %%
df_2019.groupby(df_2019['mes_venda'])['Qtde'].sum()
# Out:
# mes_venda
# 1    1541
# 2     128
# 3     460
# 4      12
# Name: Qtde, dtype: int64

# %%
df_2019.groupby(df_2019['mes_venda'])['Qtde'].sum().plot(marker = 'o')
plt.xlabel('Mes')
plt.ylabel('Total Produtos Vendidos');
plt.legend()

# %%
plt.hist(df['Qtde'], color= 'orangered');

# %%
plt.scatter(x=df_2019['dia_venda'], y = df_2019['Receita'])

# %%
df_2019.groupby(df_2019['mes_venda'])['Qtde'].sum().plot(marker = 'o')
plt.title('total de produtos vendidos x mes')
plt.xlabel('Mes')
plt.ylabel('Total Produtos Vendidos');
plt.legend()
plt.savefig('gratico QTDE x MES.png')
